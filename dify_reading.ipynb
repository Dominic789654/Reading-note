# %%
https://arxiv.org/html/2405.13576

# %%
import requests
import json

url = "https://api.dify.ai/v1/workflows/run"

headers = {
    'Authorization': 'Bearer app-Xqv9LGYgExCnx1Hmk8lmekJG',
    'Content-Type': 'application/json',
}

data = {
    "inputs": {
        "Target_language": 'Chinese',
        "Input_language": 'English',
        "URL": 'https://arxiv.org/html/2410.08815',
        "Type":'xhs'
    },
    "response_mode": "blocking",
    "user": "XiangLIU"
}

response = requests.post(url, headers=headers, data=json.dumps(data))

# %%
response.json()['data']['outputs']['output']
# save to file
with open('output.md', 'w') as f:
    f.write(response.json()['data']['outputs']['output'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/anaconda3/envs/lmflow/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/opt/anaconda3/envs/lmflow/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
print("📖标题：FlashRAG：高效的检索增强生成研究模块化工具包  \n🌐来源：arXiv, 2405.13576\n\n🛎️文章简介  \n🔸研究问题：在大型语言模型（LLMs）迅速发展的背景下，如何有效利用检索增强生成（RAG）技术以减少幻觉问题并提升模型性能？  \n🔸主要贡献：提出了FlashRAG，一个高效且模块化的开源工具包，旨在帮助研究者轻松复现已有的RAG方法，并在统一框架内开发新的RAG算法。\n\n📝重点思路  \n🔺FlashRAG工具包概述  \n1️⃣ **广泛且可定制的模块化框架**：提供13个组件，包括判断器、检索器、重排序器、精炼器和生成器，可以单独使用或组合成完整的流水线。  \n2️⃣ **预实现的先进RAG算法**：实现12种先进的RAG算法，如Self-RAG和FLARE，经过统一设置评估，提高整体可复现性。  \n3️⃣ **全面的基准数据集**：整理并预处理32个常见的数据集，以确保一致性和可重用性，并托管在Hugging Face平台上供用户访问。  \n4️⃣ **高效辅助脚本**：提供易于使用的脚本，包括下载维基百科数据、构建索引等步骤，减少实验准备时间。\n\n🔺组件模块详解  \n- **Judger（判断器）**：用于评估查询是否需要检索。  \n- **Retriever（检索器）**：支持多种稀疏和密集检索方法，如BM25与BERT基础模型。  \n- **Refiner（精炼器）**：对输入文本进行精炼，以减少生成时所需的token数量，提高最终响应质量。  \n- **Generator（生成器）**：负责最终文本生成，与多个主流LLM加速库兼容。\n\n🔺流水线模块与数据集支持  \n- 流水线模块允许用户根据需要组合不同组件形成完整的RAG流程，例如“查询 -> 检索 -> 后处理（重排序、精炼） -> 生成”。   \n- 提供维基百科文档作为知识基础，为各种实验提供支持。\n\n🔎实验结果与讨论  \n通过FlashRAG，研究者能够对不同的RAG方法进行基准测试。在主要实验中，结合最新版本LLAMA3作为生成器与E5-base-v2作为检索器，对六个常见数据集进行了测试，结果表明标准的RAG方法显著提升了性能。\n\n![标准 RAG 过程下不同文档数量与检索效果](https://arxiv.org/html/2405.13576/path/to/S4.F2.png)  \n\n## 结论\nFlashRAG为研究人员提供了一个解决方案，以应对复现实验时面临的问题，并降低研发成本。该工具包不仅包括全面的数据集和先进算法，还提供便捷脚本，使得研究者能够专注于优化新算法。\n\n💡个人观点\nFlashRAG作为一个模块化工具包，为相关领域提供了灵活而强大的支持，有助于推动检索增强生成技术的发展，同时提高了研究工作的效率和可重复性。\n\n#FlashRAG #大语言模型 #检索增强生成 #论文分享 #人工智能 #科研工具")
# Out:
# 📖标题：FlashRAG：高效的检索增强生成研究模块化工具包
# 🌐来源：arXiv, 2405.13576
#
# 🛎️文章简介
# 🔸研究问题：在大型语言模型（LLMs）迅速发展的背景下，如何有效利用检索增强生成（RAG）技术以减少幻觉问题并提升模型性能？
# 🔸主要贡献：提出了FlashRAG，一个高效且模块化的开源工具包，旨在帮助研究者轻松复现已有的RAG方法，并在统一框架内开发新的RAG算法。
#
# 📝重点思路
# 🔺FlashRAG工具包概述
# 1️⃣ **广泛且可定制的模块化框架**：提供13个组件，包括判断器、检索器、重排序器、精炼器和生成器，可以单独使用或组合成完整的流水线。
# 2️⃣ **预实现的先进RAG算法**：实现12种先进的RAG算法，如Self-RAG和FLARE，经过统一设置评估，提高整体可复现性。
# 3️⃣ **全面的基准数据集**：整理并预处理32个常见的数据集，以确保一致性和可重用性，并托管在Hugging Face平台上供用户访问。
# 4️⃣ **高效辅助脚本**：提供易于使用的脚本，包括下载维基百科数据、构建索引等步骤，减少实验准备时间。
#
# 🔺组件模块详解
# - **Judger（判断器）**：用于评估查询是否需要检索。
# - **Retriever（检索器）**：支持多种稀疏和密集检索方法，如BM25与BERT基础模型。
# - **Refiner（精炼器）**：对输入文本进行精炼，以减少生成时所需的token数量，提高最终响应质量。
# - **Generator（生成器）**：负责最终文本生成，与多个主流LLM加速库兼容。
#
# 🔺流水线模块与数据集支持
# - 流水线模块允许用户根据需要组合不同组件形成完整的RAG流程，例如“查询 -> 检索 -> 后处理（重排序、精炼） -> 生成”。
# - 提供维基百科文档作为知识基础，为各种实验提供支持。
#
# 🔎实验结果与讨论
# 通过FlashRAG，研究者能够对不同的RAG方法进行基准测试。在主要实验中，结合最新版本LLAMA3作为生成器与E5-base-v2作为检索器，对六个常见数据集进行了测试，结果表明标准的RAG方法显著提升了性能。
#
# ...
